# %% [markdown]
# # Project Part 1>> Automobile Data Exploration I

# %%
import pandas as pd

# %%
Automobile = pd.read_csv("D:/ML/Practice Assignment/Lesson 3 Practice/mtcars.csv")

# %%
Automobile
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
Automobile.ndim
# Out:
# 2

# %%
Automobile.shape
# Out:
# (32, 12)

# %%
type(Automobile)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
Automobile_avg_hp = np.mean(Automobile['hp'])

# %%
Automobile_avg_hp
# Out:
# 146.6875

# %%
Automobile.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,10))
correlations = Automobile.corr()
sns.heatmap(data = correlations, square = True, cmap="bwr", annot= True)
plt.yticks(rotation = 0)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# ## As per my observation in I can say "cyl, disp, hp, drat, wt" are mostly corelated features here.

# %% [markdown]
# # Project Part 2 >> Using the loaded dataset, perform different data exploration techniques and obtain their respective results.

# %%
Automobile['hp'].unique()
# Out:
# array([110,  93, 175, 105, 245,  62,  95, 123, 180, 205, 215, 230,  66,
#         52,  65,  97, 150,  91, 113, 264, 335, 109], dtype=int64)

# %%
Automobile['hp'].nunique()
# Out:
# 22

# %%
Automobile.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
Automobile.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
Automobile['gear'].unique()
# Out:
# array([4, 3, 5], dtype=int64)

# %%
Automobile['gear'].nunique()
# Out:
# 3

# %%
Automobile['gear'].mode()
# Out:
# 0    3
# dtype: int64

# %%
Automobile['cyl'].mode()
# Out:
# 0    8
# dtype: int64

# %%
Automobile['mpg'].mean()
# Out:
# 20.090624999999996

# %% [markdown]
# # Project part 3

# %%
#Check for missing values and outliers within the horsepower column and remove them.

# %%
Automobile['hp'].isna().any()
# Out:
# False

# %%
# There is no missing values in the horsepower column.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,7))
Automobile.boxplot(['hp'])
# Out:
# <AxesSubplot:>

# %%
#Outlier detection:

# %%
import seaborn as sns
sns.boxplot(x = Automobile['hp'])
# Out:
# <AxesSubplot:xlabel='hp'>

# %%
filter = Automobile['hp'].values > 260
Automobile_outlier_remove = Automobile[filter]

# %%
Automobile_outlier_remove
# Out:
#              model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  \
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5
#
#     carb
# 28     4
# 30     8

# %%
Automobile['hp'].
# Out:
#   File "<ipython-input-147-25e0d1ae92f5>", line 1
#     Automobile['hp'].
#                      ^
# SyntaxError: invalid syntax

# %%
Automobile = pd.read_csv("D:/ML/Practice Assignment/Lesson 3 Practice/mtcars.csv", index_col = "model")

# %%
Automobile
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
filter = Automobile['hp'].values > 260
Automobile_outlier_remember = Automobile[filter]
Automobile_outlier_remember
# Out:
#                  mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# model
# Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5     4
# Maserati Bora   15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
Automobile_final = Automobile.drop(['Ford Pantera L','Maserati Bora'])

# %%
Automobile_final
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...
